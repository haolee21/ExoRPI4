# %%
import pandas as pd
import os
from matplotlib import pyplot as plt
from DataLoad import DataProcess

# %%
## force calibration

# %%
data_cali=pd.read_csv('Force_cali/154931_Apr172022.csv')
import numpy as np
print("force bias=",np.mean(data_cali['force']))
# Out:
# force bias= 558.1535

# %%
data = DataProcess('Force_cali/155216_Apr172022.csv',force_bias=558.1535)

# %%
area=0.31*0.00064516 #unit m^2
area_2 = 0.28*0.00064516

# %%
fig,ax = plt.subplots()
ax.plot(data['time'],data['tank_pre']*area_2*2,label='Pressure')
ax.plot(data['time'],data['force'],label='Force')
ax.legend()

# %%
data = DataProcess('Force_cali/160424_Apr172022.csv',force_bias=558.1535)
fig,ax = plt.subplots()
ax.plot(data['time'],data['tank_pre']*area_2*2,label='Pressure')
ax.plot(data['time'],data['force'],label='Force')
ax.legend()

# %%
data = DataProcess('Force_cali/160625_Apr172022.csv',force_bias=558.1535)
fig,ax = plt.subplots()
ax.plot(data['time'],data['tank_pre']*area_2,label='Pressure')
ax.plot(data['time'],data['force']/2,label='Force')
ax.legend()

# %%
data = DataProcess('Force_cali/161913_Apr172022.csv',force_bias=558.1535)
fig,ax = plt.subplots()
ax.plot(data['time'],data['tank_pre']*area,label='Pressure')
ax.plot(data['time'],data['force'],label='Force')
ax.legend()

# %%
data = DataProcess('Force_cali/162604_Apr172022.csv',force_bias=558.1535)
fig,ax = plt.subplots()
ax.plot(data['time'],data['tank_pre']*area_2,label='Pressure')
ax.plot(data['time'],data['force']/2,label='Force')
ax.legend()

# %%
data = DataProcess('Force_cali/162732_Apr172022.csv',force_bias=558.1535)
fig,ax = plt.subplots()
ax.plot(data['time'],data['tank_pre']*area,label='Pressure')
ax.plot(data['time'],data['force']/2,label='Force')
ax.legend()

# %%
data = DataProcess('Force_cali/162932_Apr172022.csv',force_bias=558.1535)
fig,ax = plt.subplots()
ax.plot(data['time'],data['tank_pre']*area_2,label='Pressure')
ax.plot(data['time'],data['force']/2,label='Force')
ax.legend()

# %%
data = DataProcess('Force_cali/163611_Apr172022.csv',force_bias=558.1535)
fig,ax = plt.subplots()
ax.plot(data['time'],data['tank_pre']*area_2,label='Pressure')
ax.plot(data['time'],data['force']/2,label='Force')
ax.legend()

# %%
data = DataProcess('Force_cali/164605_Apr172022.csv',force_bias=558.1535)
fig,ax = plt.subplots()
ax.plot(data['time'],data['tank_pre']*area_2,label='Pressure')
ax.plot(data['time'],data['force']/2,label='Force')
ax.legend()

# %%
data = DataProcess('Force_cali/165723_Apr172022.csv',force_bias=558.1535)
fig,ax = plt.subplots()
ax.plot(data['time'],data['tank_pre']*area_2,label='Pressure')
ax.plot(data['time'],data['force'],label='Force')
ax.legend()

# %%
data = DataProcess('Force_cali/173813_Apr172022.csv',force_bias=558.1535)
fig,ax = plt.subplots()
ax.plot(data['time'],data['tank_pre']*area_2,label='Pressure')
ax.plot(data['time'],data['force']/2,label='Force')
ax.legend()

# %%
data = DataProcess('Force_cali/173948_Apr172022.csv',force_bias=558.1535)
fig,ax = plt.subplots()
ax.plot(data['time'],data['tank_pre']*area_2,label='Pressure')
ax.plot(data['time'],data['force'],label='Force')
ax.legend()

# %%
data = DataProcess('Force_cali/174654_Apr172022.csv',force_bias=558.1535)
fig,ax = plt.subplots()
ax.plot(data['time'],data['tank_pre']*area_2,label='Pressure')
ax.plot(data['time'],data['force']/2,label='Force')
ax.legend()

# %%
data = DataProcess('Force_cali/175136_Apr172022.csv',force_bias=558.1535)
fig,ax = plt.subplots()
ax.plot(data['time'],data['tank_pre']*area_2,label='Pressure')
ax.plot(data['time'],data['force']/2,label='Force')
ax.legend()

# %%
data = DataProcess('Force_cali/180254_Apr172022.csv',force_bias=558.1535)
fig,ax = plt.subplots()
ax.plot(data['time'],data['tank_pre']*area_2,label='Pressure')
ax.plot(data['time'],data['force']/2,label='Force')
ax.legend()

# %%
data = DataProcess('Force_cali/181909_Apr172022.csv',force_bias=558.1535)
fig,ax = plt.subplots()
ax.plot(data['time'],data['tank_pre']*area_2,label='Pressure')
ax.plot(data['time'],data['force'],label='Force')
ax.legend()

# %%
data = DataProcess('Force_cali/182731_Apr172022.csv',force_bias=269.6642)
fig,ax = plt.subplots()
ax.plot(data['time'],data['tank_pre']*area_2,label='Pressure')
ax.plot(data['time'],data['force'],label='Force')
ax.legend()

# %%
data = DataProcess('Force_cali/184024_Apr172022.csv',force_bias=615.7277333333334)
fig,ax = plt.subplots()
ax.plot(data['time'],data['tank_pre']*area_2,label='Pressure')
ax.plot(data['time'],data['force']/2,label='Force')
ax.legend()
