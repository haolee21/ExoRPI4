# %%
import pandas as pd
import os
from matplotlib import pyplot as plt
from DataLoad import DataProcess,LoadSameDuty,AddDelay,DelaySingleData

# %%
data1 = DataProcess('170821_Mar312022.csv',)

# %%
fig,ax=plt.subplots(3,1,figsize=(20,10))
ax[0].plot(data1['time'],data1['cyln_pre'],label='Cylinder')
ax[0].plot(data1['time'],data1['tank_pre'],label='Tank')
ax[0].set_ylabel('Pressure (Pa)')
ax[0].legend()
ax[1].plot(data1['time'],data1['force'])
ax[1].set_ylabel('Force (N)')
ax[2].plot(data1['time'],data1['pos'])
ax[2].set_ylabel('Pos (m)')
# Out:
# Text(0, 0.5, 'Pos (m)')

# %%
data1 = DataProcess('171234_Mar312022.csv',)
fig,ax=plt.subplots(3,1,figsize=(20,10))
ax[0].plot(data1['time'],data1['cyln_pre'],label='Cylinder')
ax[0].plot(data1['time'],data1['tank_pre'],label='Tank')
ax[0].set_ylabel('Pressure (Pa)')
ax[0].legend()
ax[1].plot(data1['time'],data1['force'])
ax[1].set_ylabel('Force (N)')
ax[2].plot(data1['time'],data1['pos'])
ax[2].set_ylabel('Pos (m)')
# Out:
# Text(0, 0.5, 'Pos (m)')

# %%
data1 = DataProcess('171510_Mar312022.csv',)
fig,ax=plt.subplots(3,1,figsize=(20,10))
ax[0].plot(data1['time'],data1['cyln_pre'],label='Cylinder')
ax[0].plot(data1['time'],data1['tank_pre'],label='Tank')
ax[0].set_ylabel('Pressure (Pa)')
ax[0].legend()
ax[1].plot(data1['time'],data1['force'])
ax[1].set_ylabel('Force (N)')
ax[2].plot(data1['time'],data1['pos'])
ax[2].set_ylabel('Pos (m)')
# Out:
# Text(0, 0.5, 'Pos (m)')

# %%
data1 = DataProcess('171550_Mar312022.csv',)
fig,ax=plt.subplots(3,1,figsize=(20,10))
ax[0].plot(data1['time'],data1['cyln_pre'],label='Cylinder')
ax[0].plot(data1['time'],data1['tank_pre'],label='Tank')
ax[0].set_ylabel('Pressure (Pa)')
ax[0].legend()
ax[1].plot(data1['time'],data1['force'])
ax[1].set_ylabel('Force (N)')
ax[2].plot(data1['time'],data1['pos'])
ax[2].set_ylabel('Pos (m)')
# Out:
# Text(0, 0.5, 'Pos (m)')

# %%
data1 = DataProcess('171654_Mar312022.csv',)
fig,ax=plt.subplots(3,1,figsize=(20,10))
ax[0].plot(data1['time'],data1['cyln_pre'],label='Cylinder')
ax[0].plot(data1['time'],data1['tank_pre'],label='Tank')
ax[0].set_ylabel('Pressure (Pa)')
ax[0].legend()
ax[1].plot(data1['time'],data1['force'])
ax[1].set_ylabel('Force (N)')
ax[2].plot(data1['time'],data1['pos'])
ax[2].set_ylabel('Pos (m)')
# Out:
# Text(0, 0.5, 'Pos (m)')
